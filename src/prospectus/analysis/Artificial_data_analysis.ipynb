# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
dataset_folder = "../../../dataset/"

# %% [markdown]
# # Artificial Dataset 1 Analysis

# %%
microsoft_df = pd.read_csv(dataset_folder + "Artificial_trend.csv")

# %%
microsoft_df['date'] = pd.to_datetime(microsoft_df['date'])
microsoft_df.set_index('date',inplace=True)
microsoft_df
# Out:
#                trend
# date
# 2000-07-01 -0.036757
# 2000-07-02 -0.038780
# 2000-07-03 -0.046137
# 2000-07-04 -0.045503
# 2000-07-05 -0.043553
# ...              ...
# 2020-06-28 -0.060778
# 2020-06-29 -0.054116
# 2020-06-30 -0.056405
# 2020-07-01 -0.052187
# 2020-07-02 -0.046809
#
# [7307 rows x 1 columns]

# %% [markdown]
# ### We will use Date and Close column for Time-series Analysis

# %%
plt.plot(microsoft_df['trend'])
plt.title('Artificial Dataset 1 Trend')
x = microsoft_df.index
plt.xticks(x[::1000],rotation=45)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
figure(figsize=(8, 6), dpi=80)

# %%
x
# Out:
# DatetimeIndex(['2000-07-01', '2000-07-02', '2000-07-03', '2000-07-04',
#                '2000-07-05', '2000-07-06', '2000-07-07', '2000-07-08',
#                '2000-07-09', '2000-07-10',
#                ...
#                '2020-06-23', '2020-06-24', '2020-06-25', '2020-06-26',
#                '2020-06-27', '2020-06-28', '2020-06-29', '2020-06-30',
#                '2020-07-01', '2020-07-02'],
#               dtype='datetime64[ns]', name='date', length=7307, freq=None)

# %% [markdown]
# ### Descriptive statistics

# %%
microsoft_df.describe()
# Out:
#              trend
# count  7307.000000
# mean     -0.006673
# std       0.057282
# min      -0.181630
# 25%      -0.046567
# 50%      -0.005817
# 75%       0.033535
# max       0.141307

# %%
microsoft_df.isnull().sum()
# Out:
# trend    0
# dtype: int64

# %% [markdown]
# ### Time-series decomposition: Seasonality, Trend, Noise

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
# rcParams['figure.figsize'] = 14, 9

result = seasonal_decompose(microsoft_df,period=365)
result.trend.plot()
plt.show()

# %% [markdown]
# ### A clear trend exists in the data.

# %% [markdown]
# # Artificial Dataset 2 Analysis

# %%
microsoft_df = pd.read_csv(dataset_folder + "Artificial_trend1.csv")

# %%
microsoft_df['date'] = pd.to_datetime(microsoft_df['date'])
microsoft_df.set_index('date',inplace=True)
microsoft_df
# Out:
#                trend
# date
# 2000-07-01 -0.030415
# 2000-07-02 -0.025551
# 2000-07-03 -0.029866
# 2000-07-04 -0.034355
# 2000-07-05 -0.028927
# ...              ...
# 2020-06-28  0.044721
# 2020-06-29  0.046374
# 2020-06-30  0.048462
# 2020-07-01  0.050580
# 2020-07-02  0.056934
#
# [7307 rows x 1 columns]

# %% [markdown]
# ### We will use Date and Close column for Time-series Analysis

# %%
plt.plot(microsoft_df['trend'])
plt.title('Artificial Dataset 2 Trend')
x = microsoft_df.index
plt.xticks(x[::1000],rotation=45)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
figure(figsize=(8, 6), dpi=80)

# %%
x
# Out:
# DatetimeIndex(['2000-07-01', '2000-07-02', '2000-07-03', '2000-07-04',
#                '2000-07-05', '2000-07-06', '2000-07-07', '2000-07-08',
#                '2000-07-09', '2000-07-10',
#                ...
#                '2020-06-23', '2020-06-24', '2020-06-25', '2020-06-26',
#                '2020-06-27', '2020-06-28', '2020-06-29', '2020-06-30',
#                '2020-07-01', '2020-07-02'],
#               dtype='datetime64[ns]', name='date', length=7307, freq=None)

# %% [markdown]
# ### Descriptive statistics

# %%
microsoft_df.describe()
# Out:
#              trend
# count  7307.000000
# mean     -0.005208
# std       0.052295
# min      -0.148866
# 25%      -0.046332
# 50%       0.001910
# 75%       0.032662
# max       0.117912

# %%
microsoft_df.isnull().sum()
# Out:
# trend    0
# dtype: int64

# %% [markdown]
# ### Time-series decomposition: Seasonality, Trend, Noise

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
# rcParams['figure.figsize'] = 14, 9

result = seasonal_decompose(microsoft_df,period=365)
result.trend.plot()
plt.show()

# %% [markdown]
# ### A clear trend exists in the data.
